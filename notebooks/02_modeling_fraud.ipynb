# %% [markdown]
# # Fraud detection – classic vs autoencoder
#
# This notebook is a thin wrapper around the scripts in `src/`:
# - `train_classic.py` – trains a supervised model with class imbalance handling.
# - `train_autoencoder.py` – trains a deep autoencoder on normal transactions.
# - `evaluate.py` – compares both approaches.
#
# Run this notebook to kick off the whole pipeline from Jupyter.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))

from train_classic import train as train_classic
from train_autoencoder import train_autoencoder
from evaluate import main as evaluate_main

# %% [markdown]
# ### 1. Train classic model

# %%
clf, classic_outputs = train_classic()

# %% [markdown]
# ### 2. Train autoencoder

# %%
ae, errors, labels = train_autoencoder()

# %% [markdown]
# ### 3. Compare models

# %%
evaluate_main()
